# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-первичный-анализ-таблицы" data-toc-modified-id="Загрузка-и-первичный-анализ-таблицы-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и первичный анализ таблицы</a></span><ul class="toc-item"><li><span><a href="#Запись-данных-в-переменные" data-toc-modified-id="Запись-данных-в-переменные-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Запись данных в переменные</a></span></li><li><span><a href="#Подготовка-данных-к-анализу" data-toc-modified-id="Подготовка-данных-к-анализу-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка данных к анализу</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Задание-функций-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Задание-функций-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задание функций для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-get_retantion" data-toc-modified-id="Функция-get_retantion-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция get_retantion</a></span></li><li><span><a href="#Функция-get_conversion" data-toc-modified-id="Функция-get_conversion-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция get_conversion</a></span></li><li><span><a href="#Функция-get_ltv" data-toc-modified-id="Функция-get_ltv-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция get_ltv</a></span></li><li><span><a href="#Функция-get_profiles" data-toc-modified-id="Функция-get_profiles-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция get_profiles</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-пользовательских-профилей" data-toc-modified-id="Создание-пользовательских-профилей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание пользовательских профилей</a></span></li><li><span><a href="#Пользователи-по-странам" data-toc-modified-id="Пользователи-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Пользователи по странам</a></span></li><li><span><a href="#Пользователи-по-устройствам" data-toc-modified-id="Пользователи-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Пользователи по устройствам</a></span></li><li><span><a href="#Рекламные-источники-привлечения" data-toc-modified-id="Рекламные-источники-привлечения-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Рекламные источники привлечения</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-маркетинг" data-toc-modified-id="Расходы-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расходы на маркетинг</a></span></li><li><span><a href="#Затраты-на-привлечение-одного-пользователя" data-toc-modified-id="Затраты-на-привлечение-одного-пользователя-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Затраты на привлечение одного пользователя</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам." data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам.</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам." data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам.</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li><li><span><a href="#Конверсия-и-удержание-с-разбивкой-по-устройствам,-странам,-рекламным-каналам" data-toc-modified-id="Конверсия-и-удержание-с-разбивкой-по-устройствам,-странам,-рекламным-каналам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Конверсия и удержание с разбивкой по устройствам, странам, рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Разбивка-по-устройствам" data-toc-modified-id="Разбивка-по-устройствам-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Разбивка по устройствам</a></span></li><li><span><a href="#Разбивка-по-странам" data-toc-modified-id="Разбивка-по-странам-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Разбивка по странам</a></span></li><li><span><a href="#Разбивка-по-рекламным-каналам" data-toc-modified-id="Разбивка-по-рекламным-каналам-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Разбивка по рекламным каналам</a></span></li></ul></li><li><span><a href="#ROI-по-параметрам" data-toc-modified-id="ROI-по-параметрам-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>ROI по параметрам</a></span><ul class="toc-item"><li><span><a href="#ROI-страны---каналы" data-toc-modified-id="ROI-страны---каналы-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>ROI страны - каналы</a></span></li><li><span><a href="#ROI-устройства---каналы" data-toc-modified-id="ROI-устройства---каналы-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>ROI устройства - каналы</a></span></li><li><span><a href="#ROI-страны---устройства" data-toc-modified-id="ROI-страны---устройства-5.6.3"><span class="toc-item-num">5.6.3&nbsp;&nbsp;</span>ROI страны - устройства</a></span></li></ul></li><li><span><a href="#Конверсия-по-параметрам" data-toc-modified-id="Конверсия-по-параметрам-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Конверсия по параметрам</a></span><ul class="toc-item"><li><span><a href="#Конверсия-страны---каналы" data-toc-modified-id="Конверсия-страны---каналы-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>Конверсия страны - каналы</a></span></li><li><span><a href="#Конверсия-устройства----канлы" data-toc-modified-id="Конверсия-устройства----канлы-5.7.2"><span class="toc-item-num">5.7.2&nbsp;&nbsp;</span>Конверсия устройства -  канлы</a></span></li><li><span><a href="#Конверсия-страны---устройства" data-toc-modified-id="Конверсия-страны---устройства-5.7.3"><span class="toc-item-num">5.7.3&nbsp;&nbsp;</span>Конверсия страны - устройства</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Максимизация-ROI" data-toc-modified-id="Максимизация-ROI-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Максимизация ROI</a></span></li><li><span><a href="#Максимизация-конверсии" data-toc-modified-id="Максимизация-конверсии-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Максимизация конверсии</a></span></li></ul></li></ul></div>

# %% [markdown]
# # <p style='text-align: center;'> Анализ маркетинга Procrastinate Pro+ </p><a class="tocSkip">
# ## Загрузка и первичный анализ таблицы
#
# **Описание данных**
#
# * visits_info_short.csv хранит лог сервера с информацией о посещениях сайта,
# * orders_info_short.csv — информацию о покупках,
# * costs_info_short.csv — информацию о расходах на рекламу.
#
# **Структура visits_info_short.csv**
#
# * User Id — уникальный идентификатор пользователя,
# * Region — страна пользователя,
# * Device — тип устройства пользователя,
# * Channel — идентификатор источника перехода,
# * Session Start — дата и время начала сессии,
# * Session End — дата и время окончания сессии.
#
#
# **Структура orders_info_short.csv**
# * User Id — уникальный идентификатор пользователя,
# * Event Dt — дата и время покупки,
# * Revenue — сумма заказа.
#
#
# **Структура costs_info_short.csv**
#
# * Channel — идентификатор рекламного источника,
# * Dt — дата проведения рекламной кампании,
# * Costs — расходы на эту кампанию.
#
#
# **Шаг 1. Загрузите данные и подготовьте их к анализу**
#
# 1.1. Положите данные о визитах, заказах и рекламных тратах в переменные.
#
# 1.2. Подготовьте данные к анализу. Убедитесь, что тип данных во всех колонках соответствует значениям. Проверьте отсутствие дубликатов.
#
#
# **Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии**
#
#
# **Шаг 3. Проведите исследовательский анализ данных**
#
#
# 3.1. Создайте пользовательские профили. Определите минимальную и максимальную даты привлечения пользователей.
#
# 3.2. Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
#
# 3.3. Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
#
# 3.4. Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# Напишите промежуточные выводы.
#
#
# **Шаг 4. Маркетинг**
#
# 4.1. Посчитайте общую сумму расходов на маркетинг. Выясните, как траты распределены по источникам. Визуализируйте изменения метрик во времени.
#
# 4.2. Узнайте, сколько в среднем стоило привлечение одного пользователя из каждого источника. Рассчитайте средний CAC на одного пользователя для всего проекта и для каждого источника трафика. Используйте профили пользователей.
#
# Напишите промежуточные выводы.
#
#
# **Шаг 5. Оцените окупаемость рекламы**
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# 5.1. Проанализируйте общую окупаемость рекламы. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# 5.2. Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# 5.3. Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# Опишите обнаруженные проблемы и напишите промежуточные выводы.
#
# 5.4. Постройте и изучите графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.
#
# Ответьте на такие вопросы:
# * Окупается ли реклама в целом?
# * Какие устройства, страны и каналы могут снижать окупаемость рекламы?
# * Чем могут быть вызваны проблемы окупаемости?
#
# Опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.
#
#
# **Шаг 6. Напишите выводы**
#
# 6.1. Выделите причины неэффективности привлечения пользователей.
#
# 6.2. Сформулируйте рекомендации для отдела маркетинга.

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import seaborn as sns 
import datetime as dt
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)
from datetime import datetime, timedelta
import numpy as np

# %matplotlib inline

# %% [markdown]
# ### Запись данных в переменные

# %%
try:
    visits = pd.read_csv(r'E:\pp+\visits_info_short.csv') # personal path
    orders = pd.read_csv(r'E:\pp+\orders_info_short.csv') # personal path
    costs = pd.read_csv(r'E:\pp+\costs_info_short.csv') # personal path
except:
    visits = pd.read_csv('https://code.s3.yandex.net/datasets/visits_info_short.csv') # Yandex path
    orders = pd.read_csv('https://code.s3.yandex.net/datasets/orders_info_short.csv') # Yandex path
    costs = pd.read_csv('https://code.s3.yandex.net/datasets/costs_info_short.csv') # Yandex path

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# Приводим названия столбцов в таблицах к нижнему регистру и заменяем пробелы на '_'

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns]
costs.columns = [x.lower().replace(' ', '_') for x in costs.columns]

# %% [markdown]
# ### Подготовка данных к анализу
#
# Проверяем типы данных и при необходимости корректируем

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# user_id          309901 non-null int64
# region           309901 non-null object
# device           309901 non-null object
# channel          309901 non-null object
# session_start    309901 non-null object
# session_end      309901 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# user_id     40212 non-null int64
# event_dt    40212 non-null object
# revenue     40212 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.5+ KB

# %%
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# channel    1800 non-null object
# costs      1800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs['dt'] = pd.to_datetime(costs['dt'])

# %% [markdown]
# Проверяем отсутствие дубликатов

# %%
print('Дубликатов в таблице visits:', visits.duplicated().sum())
print('Дубликатов в таблице orders:', orders.duplicated().sum())
print('Дубликатов в таблице costs:', costs.duplicated().sum())
# Out:
# Дубликатов в таблице visits: 0
# Дубликатов в таблице orders: 0
# Дубликатов в таблице costs: 0

# %% [markdown]
# ### Вывод
#
# Скорректировали названия колонок, временнЫе данные в таблицах привели к типу DateTime. Дубликатов не обнаружили.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Ты многократно писал очень схожие куски кода, но можно ведь сделать функции для первичного анализа датафреймов, смотреть распределение численных значений при помощи `describe`, анализировать какие строки наиболее частые при помощи `value_counts`, ну и `head` с `info` в эту же функцию первичного анализа стоит поместить, и при помощи нее можно получать первоначальную информацию о каждом датасете по вызову функции к каждому новому датасету, ну и такую функцию переносить из проекта в проект, чтобы максимально упрощать себе первичный анализ и оставлять больше сил и времени на исследования).
#
# Безусловно в этом проекте нет необходимости в глубоком анализе данных, но например можно добавить переименование столбцов в неё
# </div>

# %% [markdown]
# ## Задание функций для расчета и анализа LTV, ROI, удержания и конверсии
#
# ### Функция get_retantion

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    #dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'event_dt']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция get_conversion

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу конверсии
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        # считаем сумму с накоплением для каждой строки
        result = result.fillna(0).cumsum(axis = 1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # добавляем размеры когорт в таблицу конверсии
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция get_ltv

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция get_profiles

# %%
def get_profiles(sessions, 
                 orders, 
#                 events, 
                 ad_costs, 
                 event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'])
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    #for event in event_names:
    #    if event in events['event_name'].unique():
    #        profiles[event] = profiles['user_id'].isin(
    #            events.query('event_name == @event')['user_id'].unique()
    #        )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ## Исследовательский анализ данных
#
# ### Создание пользовательских профилей

# %%
profiles = get_profiles(visits, orders, costs, event_names=[])

# %%
display(profiles.head(5))
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# **Минимальная и максимальная дата привлечения пользователей:**

# %%
print('Минимальная дата привлечения пользователей:', profiles['dt'].dt.date.min())
print('Максимальная дата привлечения пользователей:', profiles['dt'].dt.date.max())
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# ### Пользователи по странам
#
# Выяснить, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построить таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
contries_all_users = (
                       profiles.groupby('region')
                       .agg({'user_id': 'count'})
                       .rename(columns={'user_id': 'number_of_all_users'})
                       .sort_values('number_of_all_users', ascending=False)
                     )

# %%
contries_payers = (
                    profiles.query('payer == True')
                    .groupby('region')
                    .agg({'user_id': 'count'})
                    .rename(columns={'user_id': 'number_of_payers'})
                    .sort_values('number_of_payers', ascending=False)
                  )

# %%
users_from_contries = contries_all_users.join(contries_payers)
users_from_contries['rate_%'] = \
round(users_from_contries['number_of_payers'] / users_from_contries['number_of_all_users'] * 100, 2)
users_from_contries
# Out:
#                number_of_all_users  number_of_payers  rate_%
# region
# United States               100002              6902    6.90
# UK                           17575               700    3.98
# France                       17450               663    3.80
# Germany                      14981               616    4.11

# %% [markdown]
# ### Пользователи по устройствам
#
# Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построить таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
devices_all_users = (
                       profiles.groupby('device')
                       .agg({'user_id': 'count'})
                       .rename(columns={'user_id': 'number_of_all_users'})
                       .sort_values('number_of_all_users', ascending=False)
                     )

# %%
devices_payers = (
                    profiles.query('payer == True')
                    .groupby('device')
                    .agg({'user_id': 'count'})
                    .rename(columns={'user_id': 'number_of_payers'})
                    .sort_values('number_of_payers', ascending=False)
                  )

# %%
users_devices = devices_all_users.join(devices_payers)
users_devices['rate_%'] = \
round(users_devices['number_of_payers'] / users_devices['number_of_all_users'] * 100, 2)
users_devices
# Out:
#          number_of_all_users  number_of_payers  rate_%
# device
# iPhone                 54479              3382    6.21
# Android                35032              2050    5.85
# PC                     30455              1537    5.05
# Mac                    30042              1912    6.36

# %% [markdown]
# ### Рекламные источники привлечения
#
# Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
channels_all_users = (
                       profiles.groupby('channel')
                       .agg({'user_id': 'count'})
                       .rename(columns={'user_id': 'number_of_all_users'})
                       .sort_values('number_of_all_users', ascending=False)
                     )

# %%
channels_payers = (
                    profiles.query('payer == True')
                    .groupby('channel')
                    .agg({'user_id': 'count'})
                    .rename(columns={'user_id': 'number_of_payers'})
                    .sort_values('number_of_payers', ascending=False)
                  )

# %%
users_channels = channels_all_users.join(channels_payers)
users_channels['rate_%'] = \
round(users_channels['number_of_payers'] / users_channels['number_of_all_users'] * 100, 2)
display(users_channels.sort_values('number_of_payers', ascending=False))
# Out:
#                     number_of_all_users  number_of_payers  rate_%
# channel
# FaceBoom                          29144              3557   12.20
# TipTop                            19561              1878    9.60
# organic                           56439              1160    2.06
# WahooNetBanner                     8553               453    5.30
# AdNonSense                         3880               440   11.34
# RocketSuperAds                     4448               352    7.91
# LeapBob                            8553               262    3.06
# OppleCreativeMedia                 8605               233    2.71
# lambdaMediaAds                     2149               225   10.47
# YRabbit                            4312               165    3.83
# MediaTornado                       4364               156    3.57

# %% [markdown]
# ### Вывод
#
# * Больше всего покупателей приходит из США, и пользователи из этой страны характеризуются большей конверсией из поситителей в покупатели (6,9%)
# * Больше всего покупателей приходит с айфоном в руках, и пользователи этих устройств первые по количеству покупок. Однако, наибольшей конверсией из поситителей в покупатели (6,36%) характеризуются пользователи Mac
# * Больше всего поситителй являюся "ограническими". Однако, они характеризуются низкой конверсией в покупатели. Больше всего платящих пользователей - с FaceBoom. Лучшая конверсия - у FaceBoom, AdNonSense и lambdaMediaAds.
# * Для увеличения прибыли стоит поработать над конверсией в покупателей "органических" поситителей, а на рекламных площадках FaceBoom, AdNonSense и lambdaMediaAds стоит увеличить количество и качество рекламы.

# %% [markdown]
# ## Маркетинг
#
# ### Расходы на маркетинг
#
# * Посчитать общую сумму расходов на маркетинг.
# * Выяснить, как траты распределены по источникам.
# * Визуализировать изменения метрик во времени.

# %% [markdown]
# Исключаем органических пользователей

# %%
profiles = profiles.query('channel != "organic"')

# %%
costs_group = (
                costs.groupby(['channel'])
                .agg({'costs':'sum'})
                .rename(columns={'costs': 'sum_costs'})
                .sort_values('sum_costs', ascending=False)
              )
display(costs_group)
total_marketing_costs = round(costs_group.sum_costs.sum())
mean_cac = round(costs_group.sum_costs.sum() / len(profiles),4)
print('Суммарные расходы на маркетинг:', total_marketing_costs)
print('Стоимость привлечения одного клиента:', mean_cac)
# Out:
#                     sum_costs
# channel
# TipTop               54751.30
# FaceBoom             32445.60
# WahooNetBanner        5151.00
# AdNonSense            3911.25
# OppleCreativeMedia    2151.25
# RocketSuperAds        1833.00
# LeapBob               1797.60
# lambdaMediaAds        1557.60
# MediaTornado           954.48
# YRabbit                944.22
# Суммарные расходы на маркетинг: 105497.0
# Стоимость привлечения одного клиента: 1.1275

# %%
costs_group = (
                costs.groupby(['dt','channel'])
                .agg({'costs':'sum'})
                .rename(columns={'costs': 'sum_costs'})
              )

# %%
df = costs.copy()

# %%
df.set_index(df['dt'],inplace=True)
df = df.drop(columns='dt')

# %%
df = df.pivot_table(
                     index=['dt'],
                     columns=['channel'],
                     values=['costs'],
                     aggfunc={'costs':'sum'}
                   )

# %%
df.plot(
         title='Затраты на маркетинг по каналам',
         grid=True,
         figsize=(15, 6)
       )
plt.ylabel('Затраты')
plt.xlabel('Дни')
# Out:
# Text(0.5, 0, 'Дни')

# %% [markdown]
# ### Затраты на привлечение одного пользователя
#
# * Узнайть, сколько в среднем стоило привлечение одного пользователя из каждого источника.
# * Рассчитать средний CAC на одного пользователя для всего проекта и для каждого источника трафика.

# %%
acquisition_costs = (
                      profiles.groupby('channel')
                      .agg({'acquisition_cost':'mean'})
                      .sort_values('acquisition_cost',ascending=True)
                    )
acquisition_costs['acquisition_cost'] = round(acquisition_costs['acquisition_cost'],3)

# %%
def addlabels(x,y):
    for i in range(len(y)):
        plt.text(y[i], x[i], y[i])
        
x=acquisition_costs.index
y=acquisition_costs['acquisition_cost']

plt.figure(figsize = (15, 6))
      
    # making the bar chart on the data
plt.barh(x, y)
      
    # calling the function to add value labels
addlabels(x, y)

    # giving title to the plot
plt.title("Затраты на привлечение одного пользователя")
      
    # giving X and Y labels
plt.xlabel("Затараты")
      
    # visualizing the plot
plt.show()

# %% [markdown]
# ### Вывод
#
# * Общие расходы на маркетинг составили **105497**
# * В среднем, по всем источникам затраты на привлечение одного пользователя **1,13**
# * Самое дорогое САС в TipTop - **2.799**

# %% [markdown]
# ## Оценка окупаемости рекламы
#
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Определяем LTV на дату 01.11.2019 c глубиной анализа 14 дней **без разбивки на категории**

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv( profiles, 
                                                       orders, 
                                                       datetime(2019, 11, 1).date(), 
                                                       14,
                                                       dimensions=[],
                                                       ignore_horizon=False,
                                                     )

# %% [markdown]
# **График LTV:**

# %%
report = ltv.drop(columns=['cohort_size'])
report.T.plot(grid=True, figsize=(15, 6), xticks=list(report.columns.values))
plt.title('LTV без разбивки')
plt.ylabel('LTV, $')
plt.xlabel('Лайфтайм')
plt.show()

# %% [markdown]
# LTV растет, как и должен

# %% [markdown]
# **График ROI (без разбивки на категории):**

# %%
roi = ltv.div(mean_cac, axis=0)
report = roi.drop(columns=['cohort_size'])
report.T.plot(grid=True, figsize=(15, 6), xticks=list(report.columns.values))
plt.title('ROI без разбивки по каналлам привлечения')
plt.ylabel('ROI')
plt.xlabel('Лайфтайм')
plt.show()

# %% [markdown]
# ROI не достигает значения 1.0 за 14 дней, т.е. за требуемый период вложения в рекламу не окупаются

# %% [markdown]
# **Динамика LTV:**

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

window = 7
report = ltv_history[[0, 1, 2]]
filter_data(report, window).plot(figsize=(15, 6), grid = True)
plt.title(f'Динамика LTV 1-го, 2-го и 3-го дней жизни (окно сглаживания {window} дней)')
plt.ylabel('LTV, $')
plt.xlabel(f'Даты привлечения пользователей')
plt.show()

# %% [markdown]
# LTV более поздних лайфтаймов выше, чем LTV более ранних.

# %% [markdown]
# **Динамика САС**

# %%
(ltv_raw.groupby('dt')
        .agg({'acquisition_cost':'mean'})
        .plot(grid=True, figsize=(15, 6))
)
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС в среднем по всем каналам привлечения')
plt.show()

# %% [markdown]
# Вложения в рекламу суильно выросли в конце Мая и дальше плавно росли

# %% [markdown]
# **Динамика ROI**

# %%
window = 7
report = roi_history[[0, 1, 13]]
filter_data(report, window).plot(figsize=(15, 6), grid = True)
plt.title(f'Динамика ROI 1-го, 2-го и 14-го дней жизни (окно сглаживания {window} дней)')
plt.ylabel('ROI')
plt.xlabel(f'Даты привлечения пользователей')
plt.show()

# %% [markdown]
# ROI более позних лайфтаймов лежат выше ранних - это логично, т.к. LTV растет с каждым днем. Видно резкое падение ROI в конце мая - соответствует резкому росту стоимости привлечения пользователя на графике динамики САС

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам.
#
# Определяем LTV на дату 01.11.2019 c глубиной анализа 14 дней **с разбивкой по рекламным каналам**

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv( profiles, 
                                                       orders, 
                                                       datetime(2019, 11, 1).date(), 
                                                       14,
                                                       dimensions=['channel'],
                                                       ignore_horizon=False
                                                     )

# %% [markdown]
# **График LTV:**

# %%
report = ltv.drop(columns=['cohort_size'])
report.T.plot(grid=True, figsize=(15, 6), xticks=list(report.columns.values))
plt.title('LTV с разбивкой по рекламным каналам')
plt.ylabel('LTV, $')
plt.xlabel('Лайфтайм')
plt.show()

# %% [markdown]
# Наибольший вклад в рост LTV вносили LambdaMediaAds и TipTOp

# %% [markdown]
# **График ROI:**

# %%
report = roi.drop(columns=['cohort_size','cac'])
report.T.plot(grid=True, figsize=(15, 6), xticks=list(report.columns.values))
plt.title('ROI с разбивкой по каналлам привлечения')
plt.ylabel('ROI')
plt.xlabel('Лайфтайм')
plt.show()

# %% [markdown]
# Вложения в lambdaMediaAds хорошо окупались. А вот TipTop оказался наименее выгодным - соотношение выручки и затрат не удовлетворительное. Наиболее эффективные рекламные каналы - **YRabbit, MediaTornado, RocketSuperAds  lambdaMediaAds и LeapBob**

# %% [markdown]
# **Динамика LTV**

# %%
window = 7
report = ltv_history[[0]]
#report.plot(figsize=(15, 6), grid = True)
#filter_data(report, window).plot(figsize=(15, 6), grid = True)
filter_data(report.pivot_table(index='dt', columns='channel'), window)\
.plot(figsize=(15, 6), grid = True)
plt.title(f'Динамика LTV 1-го дня жизни (окно сглаживания {window} дней)')
plt.ylabel('LTV, $')
plt.xlabel(f'Даты привлечения пользователей')
plt.show()

# %% [markdown]
# **Динамика САС**

# %%
ltv_raw.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(15, 6))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС с разбивкой по каналам привлечения')
plt.show()

# %% [markdown]
# Затраты на рекламу в Tip Top существенно выше остальных и постоянно растут. Именно вложения в этот канал сформировали форму кривой суммарных затрат на рекламу.

# %% [markdown]
# **Динамика ROI**

# %%
window = 7
report = roi_history[[0]]
filter_data(report.pivot_table(index='dt', columns='channel'), window)\
.plot(figsize=(15, 6), grid = True)
plt.title(f'Динамика ROI 1-го дня жизни (окно сглаживания {window} дней)')
plt.ylabel('ROI')
plt.xlabel(f'Даты привлечения пользователей')
plt.show()

# %% [markdown]
# Самый дорогой канал TipTop по возврату инвестиций - в самом низу. A YRabbit - чаще других достигает пиковых значений.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам.
#
# Определяем LTV на дату 01.11.2019 c глубиной анализа 14 дней **с разбивкой по странам**

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv( profiles, 
                                                       orders, 
                                                       datetime(2019, 11, 1).date(), 
                                                       14,
                                                       dimensions=['region'],
                                                       ignore_horizon=False
                                                     )

# %% [markdown]
# **График LTV:**

# %%
report = ltv.drop(columns=['cohort_size'])
report.T.plot(grid=True, figsize=(15, 6), xticks=list(report.columns.values))
plt.title('LTV с разбивкой по странам')
plt.ylabel('LTV, $')
plt.xlabel('Лайфтайм')
plt.show()

# %% [markdown]
# Выручка в США самая большая

# %% [markdown]
# **График ROI:**

# %%
report = roi.drop(columns=['cohort_size','cac'])
report.T.plot(grid=True, figsize=(15, 6), xticks=list(report.columns.values))
plt.title('ROI с разбивкой по каналлам привлечения')
plt.ylabel('ROI')
plt.xlabel('Лайфтайм')
plt.show()

# %% [markdown]
# Вложения в рекламу в UK, Германии и Франции окупаются уже на 4 день. А в США не окупаются в требуемый срок в 14 дней.

# %% [markdown]
# **Динамика LTV**

# %%
window = 7
report = ltv_history[[0]]
#report.plot(figsize=(15, 6), grid = True)
#filter_data(report, window).plot(figsize=(15, 6), grid = True)
filter_data(report.pivot_table(index='dt', columns='region'), window)\
.plot(figsize=(15, 6), grid = True)
plt.title(f'Динамика LTV 1-го дня жизни (окно сглаживания {window} дней)')
plt.ylabel('LTV, $')
plt.xlabel(f'Даты привлечения пользователей')
plt.show()

# %% [markdown]
# **Динамика САС**

# %%
ltv_raw.pivot_table(
    index='dt', columns='region', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(15, 6))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС с разбивкой по странам')
plt.show()

# %% [markdown]
# Самая высокая стоимость привлечения - в США. Форма кривой очень похожа на форму кривой затрат на TipTop. Скорее всего, реклама в канале TipTop, была ориентирована на США.

# %% [markdown]
# **Динамика ROI**

# %%
window = 7
report = roi_history[[0]]
filter_data(report.pivot_table(index='dt', columns='region'), window)\
.plot(figsize=(15, 6), grid = True)
plt.title(f'Динамика ROI 1-го дня жизни (окно сглаживания {window} дней)')
plt.ylabel('ROI')
plt.xlabel(f'Даты привлечения пользователей')
plt.show()

# %% [markdown]
# ROI в США падает с ростом стоимости привлечения пользователя в этой стране.

# %% [markdown]
# ### Промежуточный вывод
#
# Рекламная компания не окупилась. Подвели вложения в TipTop в США. Доход от этого источника не покрыл затрат.

# %% [markdown]
# ### Конверсия и удержание с разбивкой по устройствам, странам, рекламным каналам

# %%
def conversion_and_retantion(attribute, window=7):
    
    # создаем таблицы конверсии
    conv_result_raw, \
    conv_result_grouped, \
    conv_result_in_time = get_conversion(
                                            profiles, 
                                            orders, 
                                            datetime(2019, 11, 1).date(), 
                                            14,
                                            dimensions=[attribute],
                                            ignore_horizon=False
                                        )
    # создаем таблицы удержания
    ret_result_raw, \
    ret_result_grouped, \
    ret_result_in_time = get_retention(
                                            profiles, 
                                            orders, 
                                            datetime(2019, 11, 1).date(), 
                                            14, 
                                            dimensions=[attribute],
                                            ignore_horizon=False
                                       )
    
    # строим график конверсии
    report = conv_result_grouped.drop(columns=['cohort_size'])
    report.T.plot(grid=True, 
                  figsize=(15, 6), 
                  xticks=list(report.columns.values),
                  ax=plt.subplot(1, 2, 1))
    plt.title('Конверсия с разбивкой по '+attribute)
    plt.ylabel('Конверсия')
    plt.xlabel('Лайфтайм')

    # строим график динамики конверсии
    report = conv_result_in_time[[0]]
    filter_data(report.pivot_table(index='dt', columns=attribute), window)\
    .plot(figsize=(15, 6), 
          grid = True,
          ax=plt.subplot(1, 2, 2))
    plt.title(f'Динамика конверсии 1-го дня жизни (окно сглаживания {window} дней)')
    plt.ylabel('Конверсия')
    plt.xlabel(f'Даты привлечения пользователей')
    plt.show()
    
    # строим график удержания
    report = ret_result_grouped.drop(columns=['cohort_size'])
    report.T.plot(grid=True, 
                  figsize=(15, 6), 
                  xticks=list(report.columns.values),
                  ax=plt.subplot(1, 2, 1))
    plt.title('Удержание с разбивкой по '+attribute)
    plt.ylabel('Удержание')
    plt.xlabel('Лайфтайм')
    
    # строим график динамики удержания
    report = ret_result_in_time[[0]]
    filter_data(report.pivot_table(index='dt', columns=attribute), window)\
    .plot(figsize=(15, 6), 
          grid = True,
          ax=plt.subplot(1, 2, 2))
    plt.title(f'Динамика удержания 1-го дня жизни (окно сглаживания {window} дней)')
    plt.ylabel('Удержание')
    plt.xlabel(f'Даты привлечения пользователей')
    plt.show()

# %% [markdown]
# #### Разбивка по устройствам

# %%
conversion_and_retantion('device', window=7)

# %% [markdown]
# Наибольшая конверсия наблюдается для пользователей iPhone и Mac

# %% [markdown]
# #### Разбивка по странам

# %%
conversion_and_retantion('region', window=7)

# %% [markdown]
# Набольшая конверсия - среди пользоватеелй из США. Они же удерживаются лучше остальных.

# %% [markdown]
# #### Разбивка по рекламным каналам

# %%
conversion_and_retantion('channel', window=7)

# %% [markdown]
# С точки зрения конверсии наилучшие результаты - у каналов **FaceBoom, AdNonSense, labdaMediaAds, TipTop, RocketSuperAds**

# %% [markdown]
# ### ROI по параметрам
#
# #### ROI страны - каналы

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv( profiles, 
                                                       orders, 
                                                       datetime(2019, 11, 1).date(), 
                                                       14,
                                                       dimensions=['region','channel'],
                                                       ignore_horizon=False
                                                     )

# %%
report = roi.drop(columns=['cohort_size','cac'])


for i, region in enumerate(profiles['region'].unique()):
    report.query('region == @region').droplevel('region').T.plot(
        grid=True,
        figsize=(20, 10),
        xticks=list(report.columns.values),
        ax=plt.subplot(2, 2, i + 1)
    )
    plt.xlabel('Лайфтайм')
    plt.ylabel('ROI')
    plt.title('ROI для = {}'.format(region))

plt.show()

# %% [markdown]
# #### ROI устройства - каналы

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv( profiles, 
                                                       orders, 
                                                       datetime(2019, 11, 1).date(), 
                                                       14,
                                                       dimensions=['device','channel'],
                                                       ignore_horizon=False
                                                     )

# %%
report = roi.drop(columns=['cohort_size','cac'])


for i, device in enumerate(profiles['device'].unique()):
    report.query('device == @device').droplevel('device').T.plot(
        grid=True,
        figsize=(20, 10),
        xticks=list(report.columns.values),
        ax=plt.subplot(2, 2, i + 1)
    )
    plt.xlabel('Лайфтайм')
    plt.ylabel('ROI')
    plt.title('ROI для = {}'.format(device))

plt.show()

# %% [markdown]
# #### ROI страны - устройства

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv( profiles, 
                                                       orders, 
                                                       datetime(2019, 11, 1).date(), 
                                                       14,
                                                       dimensions=['region','device'],
                                                       ignore_horizon=False
                                                     )

# %%
report = roi.drop(columns=['cohort_size','cac'])


for i, region in enumerate(profiles['region'].unique()):
    report.query('region == @region').droplevel('region').T.plot(
        grid=True,
        figsize=(20, 10),
        xticks=list(report.columns.values),
        ax=plt.subplot(2, 2, i + 1)
    )
    plt.xlabel('Лайфтайм')
    plt.ylabel('ROI')
    plt.title('ROI для = {}'.format(region))

plt.show()

# %% [markdown]
# Ожидаемо, тип устройства не сильно влияет на окупаемость рекламы от страны к стране. Однако, незначительные отличия все же есть. Например, окупаемость рекламы в США выше среди пользователей Андроид. А во Франции - на Андроиде она, наоборот, самая низкая

# %% [markdown]
# ### Конверсия по параметрам
#
# #### Конверсия страны - каналы

# %%
conv_result_raw, \
conv_result_grouped, \
conv_result_in_time = get_conversion(
                                            profiles, 
                                            orders, 
                                            datetime(2019, 11, 1).date(), 
                                            14,
                                            dimensions=['region','channel'],
                                            ignore_horizon=False
                                    )

# %%
report = conv_result_grouped.drop(columns=['cohort_size'])


for i, region in enumerate(profiles['region'].unique()):
    report.query('region == @region').droplevel('region').T.plot(
        grid=True,
        figsize=(20, 10),
        xticks=list(report.columns.values),
        ax=plt.subplot(2, 2, i + 1)
    )
    plt.xlabel('Лайфтайм')
    plt.ylabel('Конверсия')
    plt.title('Конверсия для = {}'.format(region))

plt.show()

# %% [markdown]
# #### Конверсия устройства -  канлы

# %%
conv_result_raw, \
conv_result_grouped, \
conv_result_in_time = get_conversion(
                                            profiles, 
                                            orders, 
                                            datetime(2019, 11, 1).date(), 
                                            14,
                                            dimensions=['device','channel'],
                                            ignore_horizon=False
                                    )

# %%
report = conv_result_grouped.drop(columns=['cohort_size'])


for i, device in enumerate(profiles['device'].unique()):
    report.query('device == @device').droplevel('device').T.plot(
        grid=True,
        figsize=(20, 10),
        xticks=list(report.columns.values),
        ax=plt.subplot(2, 2, i + 1)
    )
    plt.xlabel('Лайфтайм')
    plt.ylabel('Конверсия')
    plt.title('Конверсия для = {}'.format(device))

plt.show()

# %% [markdown]
# #### Конверсия страны - устройства

# %%
conv_result_raw, \
conv_result_grouped, \
conv_result_in_time = get_conversion(
                                            profiles, 
                                            orders, 
                                            datetime(2019, 11, 1).date(), 
                                            14,
                                            dimensions=['region','device'],
                                            ignore_horizon=False
                                    )

# %%
report = conv_result_grouped.drop(columns=['cohort_size'])


for i, region in enumerate(profiles['region'].unique()):
    report.query('region == @region').droplevel('region').T.plot(
        grid=True,
        figsize=(20, 10),
        xticks=list(report.columns.values),
        ax=plt.subplot(2, 2, i + 1)
    )
    plt.xlabel('Лайфтайм')
    plt.ylabel('Конверсия')
    plt.title('Конверсия для = {}'.format(region))

plt.show()

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Вывод по результатам проведенной рекламной компании**
#
# Кампания была убыточной. Подвели вложения в TipTop в США. В этот канал была вложена большАя часть бюджета, но он оакзался не прибыльным.
#
#
# Основная идея рекомендации - распределять рекламный бюджет между каналами, обеспечивающими максимизацию целевых показателей, коими могут быть:
#
# * максимизация прибыльности рекламной кампании, т.е. максимум выручки на каждый вложенный в рекламу доллар (ROI);
# * максимизация количества клиентов, т.е. конверсии из визитеров в покупатели.
#
# Конверсия и ROI, с одной стороны, коррелируют, с другой строны, для достижения максимизации этих параметров требуется вкладывать деньги в разные рекламные каналы, потому что одни каналы максимизируют прибыль, а другие - конверсию. В условии задачи не сказано, чего хочет достичь компания, поэтому рассмотрим две этих стратегии отдельно.

# %% [markdown]
# ### Максимизация ROI

# %% [markdown]
# По результатам пункта 5.6.2 делаем вывод о том, какие каналы обеспечивают наивысший ROI для каждого типа устройств:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# По результатам пункта 5.6.1 делаем вывод о том, какие каналы обеспечивают наивысший ROI для каждой страны:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Совместив эти два вывода получаем, что наиболее прибыльными по странам и по устройствам будут вложения в следущие каналы:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Максимизация конверсии

# %% [markdown]
# По результатам пункта 5.7.2 делаем вывод о том, какие каналы обеспечивают наибольшую конверсию для каждого типа устройств:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# По результатам пункта 5.7.1 делаем вывод о том, какие каналы обеспечивают наибольшую конверсию для каждой страны:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Совместив эти два вывода получаем, что наибольшую конверсию по странам и по устройствам обеспечат вложения в следущие каналы:
#
# ![image.png](attachment:image.png)
